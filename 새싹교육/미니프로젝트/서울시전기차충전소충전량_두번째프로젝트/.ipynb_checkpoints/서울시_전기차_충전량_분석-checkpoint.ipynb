# %% [markdown]
# # 데이터 출처 - 공공데이터포털
#
# - 한국전력공사_서울시 전기차 충전소 충전량
# - https://www.data.go.kr/data/15100212/fileData.do
# - 2021.1.1-2022.3.31 기간의 서울시에 위치하고 있는 한국전력공사의 전기차 충전소의 충전량을 제공합니다.
# - 데이터 사이즈가 큰 관계로 21년도 데이터만 사용합니다.<br>참고 : https://colab.research.google.com/drive/1EkpAURXDs5mpLRpIVtlImUayJBgiOPiX#scrollTo=KZYY5LGUIQ1Q&uniqifier=1

# %% [markdown]
# ###분석 목표
#
# - 서울시 자치구별 전기차 충전소 충전량 분석
# -

# %% [markdown]
# ### 기본설정

# %%
# 구글마운트
from google.colab import drive
drive.mount('/content/drive')

# 한글폰트
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %%
# 주피터에서 실행하는 한글패치
# 단점 매번 실행 시켜야됨...
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import font_manager, rc

f_path = 'c:/Windows/Fonts/malgun.ttf'
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

# %% [markdown]
# ### 데이터 불러오기 및 수정(drop, endcoding, new_column)

# %%
# 패키지 설정
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#file_path = '/content/drive/MyDrive/새싹교육/미니프로젝트/서울시 전기차 충전소 충전량/21년도_서울시_전기차_충전소.csv'

# 주피터에서 실행할시
file_path = './21년도_서울시_전기차_충전소.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# #### 컬럼 수정

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
# 시간 -> 분으로 변경
df['총_충전분'] = df['충전시간'] * 60 + df['충전분']

# %%
# 시작, 종료 데이터 -> 평일, 주말 구분
from datetime import datetime, date

new = []
for y, m, d in  df[['시작_연도', '시작_월', '시작_일']].to_numpy():

    day = datetime(y, m, d)
    day_num = day.weekday()
    if day_num == 5 or day_num ==6:
        # 주말
        day_num = '주말'
        new.append(day_num)
    else:
        # 평일
        day_num = '평일'
        new.append(day_num)

df['평일_주말'] = new

# %%
# 주소 컬럼데이터 확인
df['주소'].unique()
# Out:
# array(['서울특별시 영등포구 경인로 878', '경기도 하남시 감북로 80', '서울특별시 강동구 구천면로 395(명일동)',
#        '서울특별시 송파구 신천동 29-5 송파구청 앞', '서울특별시 송파구 송파동 오금로32길 14',
#        '서울특별시 송파구 가락동 154', '서울특별시 강동구 둔촌동 522-9',
#        '서울특별시 강동구 강일동 아리수로93길 40', '서울특별시 송파구 양재대로 932',
#        '서울특별시 송파구 장지동 516', '서울특별시 강동구 구천면로 42길 60(천호동)',
#        '서울특별시 송파구 잠실동 잠실로 88', '서울특별시 송파구 올림픽로 135',
#        '서울특별시 강동구 성내동 풍성로 128', '서울특별시 강동구 천호동 천호대로 1089',
#        '서울특별시 송파구 거여동 양산로4길 8', '서울특별시 송파구 거여동 195-1',
#        '서울특별시 송파구 위례광장로 163 (장지동, 위례22단지)', '서울특별시 송파구 신천동 7-11',
#        '서울특별시 강동구 명일동 260-1', '서울특별시 송파구 가락동 동남로 193',
#        '서울특별시 송파구 풍납동 403-11', '서울특별시 강동구 양재대로 1571',
#        '서울특별시 성북구 삼선교로16길 35 (삼선동3가, 삼선 SK VIEW 아파트)',
#        '서울특별시 성북구 하월곡동 종암로 167', '서울특별시 성북구 북악산로 844',
#        '서울특별시 성북구 석관동 화랑로48길 16', '서울특별시 성북구 장위동 월계로36길 27',
#        '서울특별시 성북구 정릉동 861-1', '서울특별시 성북구 정릉동 북악산로 851',
#        '서울특별시 성북구 돌곶이로8길 22 (석관동, 래미안아트리치)',
#        '서울특별시 성북구 보문로29다길 31 (삼선동2가, 삼선푸르지오)', '서울특별시 강북구 미아동 삼양로 256',
#        '서울특별시 성북구 정릉로 404', '서울특별시 성북구 돈암동 동소문로34길 73',
#        '서울특별시 강북구 미아동 숭인로7가길 37', '서울특별시 성북구 회기로5길 100 (하월곡동, 샹그레빌아파트)',
#        '서울특별시 성북구 종암로25길 30 (종암동, 삼성 래미안아파트)', '서울특별시 강북구 도봉로 242',
#        '서울특별시 성북구 장월로1길 28', '서울특별시 강북구 오현로 156 (번동, 해모로아파트)',
#        '서울특별시 강북구 도봉로 352', '서울특별시 성북구 돈암동 아리랑로 89',
#        '서울특별시 강북구 월계로21가길 41', '서울특별시 성북구 동소문동7가 동소문로15길 99',
#        '서울특별시 성북구 보문동4가 인촌로2길 37', '서울특별시 성북구 길음로 16',
#        '서울특별시 성북구 아리랑로5길 85', '서울특별시 강북구 월계로 173 (번동, 북서울꿈의숲)',
#        '서울특별시 성북구 동소문로 315 (길음동, 현대백화점미아점)',
#        '서울특별시 강북구 삼각산로 85 (수유동, 강북문화예술회관)', '서울특별시 중구 퇴계로 140'],
#       dtype=object)

# %%
# 주소 컬럼에서 서울 자치구 분리
df['자치구'] = df['주소'].str.extract('(\w*구)')

# %%
# 데이터 정보확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 487504 entries, 0 to 487503
# Data columns (total 22 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   충전구분    487504 non-null  object
#  1   충전소명    487504 non-null  object
#  2   주소      487504 non-null  object
#  3   충전기용량   487504 non-null  int64
#  4   충전량     487504 non-null  float64
#  5   충전시간    487504 non-null  int64
#  6   충전분     487504 non-null  int64
#  7   충전시작시각  487504 non-null  object
#  8   충전종료시각  487504 non-null  object
#  9   시작_연도   487504 non-null  int64
#  10  시작_월    487504 non-null  int64
#  11  시작_일    487504 non-null  int64
#  12  시작_시    487504 non-null  int64
#  13  시작_분    487504 non-null  int64
#  14  종료_연도   487504 non-null  int64
#  15  종료_월    487504 non-null  int64
#  16  종료_일    487504 non-null  int64
#  17  종료_시    487504 non-null  int64
#  18  종료_분    487504 non-null  int64
#  19  총_충전분   487504 non-null  int64
#  20  평일_주말   487504 non-null  object
#  21  자치구     479747 non-null  object
# dtypes: float64(1), int64(14), object(7)
# memory usage: 81.8+ MB

# %%
# Nan값 존재 X
df.isnull().sum()
# Out:
# 충전구분         0
# 충전소명         0
# 주소           0
# 충전기용량        0
# 충전량          0
# 충전시간         0
# 충전분          0
# 충전시작시각       0
# 충전종료시각       0
# 시작_연도        0
# 시작_월         0
# 시작_일         0
# 시작_시         0
# 시작_분         0
# 종료_연도        0
# 종료_월         0
# 종료_일         0
# 종료_시         0
# 종료_분         0
# 총_충전분        0
# 평일_주말        0
# 자치구       7757
# dtype: int64

# %%
# 자치구에 있는 nan 행 제거
df.dropna(axis=0, inplace=True)

# %%
df.isnull().sum()
# Out:
# 충전구분      0
# 충전소명      0
# 주소        0
# 충전기용량     0
# 충전량       0
# 충전시간      0
# 충전분       0
# 충전시작시각    0
# 충전종료시각    0
# 시작_연도     0
# 시작_월      0
# 시작_일      0
# 시작_시      0
# 시작_분      0
# 종료_연도     0
# 종료_월      0
# 종료_일      0
# 종료_시      0
# 종료_분      0
# 총_충전분     0
# 평일_주말     0
# 자치구       0
# dtype: int64

# %%
df['자치구'].unique()
# Out:
# array(['영등포구', '강동구', '송파구', '양천구', '강서구', '관악구', '동작구', '서초구', '강남구',
#        '금천구', '구로구', '동대문구', '중랑구', '광진구', '성동구', '도봉구', '노원구', '서대문구',
#        '은평구', '마포구', '용산구', '중구', '종로구', '강북구', '성북구'], dtype=object)

# %% [markdown]
# #### 데이터 문자형 -> 수치형으로 변환

# %%
from sklearn.preprocessing import LabelEncoder

# 자치구
le = LabelEncoder()
df['자치구_le'] = le.fit_transform(df['자치구'])
le_place = le.classes_

# 충전소명
le = LabelEncoder()
df['충전소명_le'] = le.fit_transform(df['충전소명'])
le_name = le.classes_

# 충전구분
le = LabelEncoder()
df['충전구분_le'] = le.fit_transform(df['충전구분'])
le_type = le.classes_

# 평일_주말
le = LabelEncoder()
df['평일_주말_le'] = le.fit_transform(df['평일_주말'])
le_rest = le.classes_

# %%
df.head(2)
# Out:
#   충전구분     충전소명                  주소  충전기용량    충전량  충전시간  충전분  \
# 0   급속  영등포전력지사  서울특별시 영등포구 경인로 878     50   0.05     0    0
# 1   급속  영등포전력지사  서울특별시 영등포구 경인로 878     50  13.10     0   29
#
#                 충전시작시각               충전종료시각  시작_연도  ...  종료_일  종료_시  종료_분  \
# 0  2021-01-01 02:06:20  2021-01-01 02:06:36   2021  ...     1     2     6
# 1  2021-01-02 14:58:37  2021-01-02 15:28:25   2021  ...     2    15    28
#
#    총_충전분  평일_주말   자치구  자치구_le  충전소명_le  충전구분_le  평일_주말_le
# 0      0     평일  영등포구      19      459        0         1
# 1     29     주말  영등포구      19      459        0         0
#
# [2 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['충전구분', '충전소명', '주소', '충전기용량', '충전량', '충전시간', '충전분', '충전시작시각', '충전종료시각',
#        '시작_연도', '시작_월', '시작_일', '시작_시', '시작_분', '종료_연도', '종료_월', '종료_일',
#        '종료_시', '종료_분', '총_충전분', '평일_주말', '자치구', '자치구_le', '충전소명_le', '충전구분_le',
#        '평일_주말_le'],
#       dtype='object')

# %%
# 수치화 진행된 컬럼 -> 데이터프레임으로 만들기
col_total = ['충전구분_le', '자치구_le', '충전소명_le','충전기용량', '충전량', '충전시간', '충전분', '총_충전분','시작_연도', '시작_월', '시작_일', '종료_연도', '종료_월', '종료_일', '평일_주말_le']
col_one = ['충전구분_le', '자치구_le', '충전소명_le','충전기용량', '충전량', '총_충전분', '시작_연도', '시작_월', '시작_일', '종료_연도', '종료_월', '종료_일', '평일_주말_le']       # 시작, 종료 데이터, 충전시간, 충전분 사용한 데이터
col_two = ['충전구분_le','자치구_le', '충전소명_le', '충전기용량', '충전량', '총_충전분', '평일_주말_le']                                                                                      # 시작, 종료 데이터는 생략, 충전시간, 충전분 두개 컬럼 합친 총_충전분

# %%
df_total = df[col_total]
df_one = df[col_one]
df_two = df[col_two]

# %%
df_total.head(2)
# Out:
#    충전구분_le  자치구_le  충전소명_le  충전기용량    충전량  충전시간  충전분  총_충전분  시작_연도  시작_월  \
# 0        0      19      459     50   0.05     0    0      0   2021     1
# 1        0      19      459     50  13.10     0   29     29   2021     1
#
#    시작_일  종료_연도  종료_월  종료_일  평일_주말_le
# 0     1   2021     1     1         1
# 1     2   2021     1     2         0

# %%
# 상관관계 확인
# 아래에서 상관관계 확인중에 nan 값으로 되어있는 컬럼들이있다.
# 이러한 컬럼들은 범주형데이터이다보니까 제외 시키고 확인을 해야한다.
df_total.corr()
# Out:
#            충전구분_le    자치구_le   충전소명_le     충전기용량       충전량      충전시간  \
# 충전구분_le   1.000000  0.015451 -0.017482 -0.998213 -0.131878  0.388461
# 자치구_le    0.015451  1.000000  0.141213 -0.015252 -0.026620 -0.013402
# 충전소명_le  -0.017482  0.141213  1.000000  0.018442  0.002720 -0.014330
# 충전기용량    -0.998213 -0.015252  0.018442  1.000000  0.131360 -0.387491
# 충전량      -0.131878 -0.026620  0.002720  0.131360  1.000000  0.143730
# 충전시간      0.388461 -0.013402 -0.014330 -0.387491  0.143730  1.000000
# 충전분       0.004634  0.003802  0.001246 -0.005337  0.064011 -0.034283
# 총_충전분     0.388644 -0.013089 -0.014222 -0.387731  0.148825  0.996742
# 시작_연도          NaN       NaN       NaN       NaN       NaN       NaN
# 시작_월     -0.013578 -0.012213  0.003411  0.013424  0.031831 -0.003701
# 시작_일     -0.002528  0.000243  0.003219  0.002246  0.004183  0.001936
# 종료_연도          NaN       NaN       NaN       NaN       NaN       NaN
# 종료_월     -0.012510 -0.012247  0.003402  0.012358  0.032187 -0.001614
# 종료_일     -0.000972 -0.000140  0.003444  0.000697  0.005312  0.003998
# 평일_주말_le -0.038667 -0.001742 -0.006473  0.039337 -0.015372 -0.024747
#
#                충전분     총_충전분  시작_연도      시작_월      시작_일  종료_연도      종료_월  \
# 충전구분_le   0.004634  0.388644    NaN -0.013578 -0.002528    NaN -0.012510
# 자치구_le    0.003802 -0.013089    NaN -0.012213  0.000243    NaN -0.012247
# 충전소명_le   0.001246 -0.014222    NaN  0.003411  0.003219    NaN  0.003402
# 충전기용량    -0.005337 -0.387731    NaN  0.013424  0.002246    NaN  0.012358
# 충전량       0.064011  0.148825    NaN  0.031831  0.004183    NaN  0.032187
# 충전시간     -0.034283  0.996742    NaN -0.003701  0.001936    NaN -0.001614
# 충전분       1.000000  0.046443    NaN  0.017545  0.004976    NaN  0.017575
# 총_충전분     0.046443  1.000000    NaN -0.002283  0.002337    NaN -0.000195
# 시작_연도          NaN       NaN    NaN       NaN       NaN    NaN       NaN
# 시작_월      0.017545 -0.002283    NaN  1.000000  0.019941    NaN  0.999805
# 시작_일      0.004976  0.002337    NaN  0.019941  1.000000    NaN  0.022194
# 종료_연도          NaN       NaN    NaN       NaN       NaN    NaN       NaN
# 종료_월      0.017575 -0.000195    NaN  0.999805  0.022194    NaN  1.000000
# 종료_일      0.005683  0.004455    NaN  0.022069  0.972569    NaN  0.019772
# 평일_주말_le -0.025085 -0.026759    NaN  0.007566 -0.021057    NaN  0.007360
#
#               종료_일  평일_주말_le
# 충전구분_le  -0.000972 -0.038667
# 자치구_le   -0.000140 -0.001742
# 충전소명_le   0.003444 -0.006473
# 충전기용량     0.000697  0.039337
# 충전량       0.005312 -0.015372
# 충전시간      0.003998 -0.024747
# 충전분       0.005683 -0.025085
# 총_충전분     0.004455 -0.026759
# 시작_연도          NaN       NaN
# 시작_월      0.022069  0.007566
# 시작_일      0.972569 -0.021057
# 종료_연도          NaN       NaN
# 종료_월      0.019772  0.007360
# 종료_일      1.000000 -0.017960
# 평일_주말_le -0.017960  1.000000

# %% [markdown]
# # 히트맵으로 확인
# plt.figure(figsize=(15, 10))
# sns.heatmap(data = df_total.corr(), annot=True)
# plt.title('전체 컬럼')
# plt.xticks(rotation=0)
# plt.show()

# %%
# 상관계수
df_one.corr()
# Out:
#            충전구분_le    자치구_le   충전소명_le     충전기용량       충전량     총_충전분  시작_연도  \
# 충전구분_le   1.000000  0.015451 -0.017482 -0.998213 -0.131878  0.388644    NaN
# 자치구_le    0.015451  1.000000  0.141213 -0.015252 -0.026620 -0.013089    NaN
# 충전소명_le  -0.017482  0.141213  1.000000  0.018442  0.002720 -0.014222    NaN
# 충전기용량    -0.998213 -0.015252  0.018442  1.000000  0.131360 -0.387731    NaN
# 충전량      -0.131878 -0.026620  0.002720  0.131360  1.000000  0.148825    NaN
# 총_충전분     0.388644 -0.013089 -0.014222 -0.387731  0.148825  1.000000    NaN
# 시작_연도          NaN       NaN       NaN       NaN       NaN       NaN    NaN
# 시작_월     -0.013578 -0.012213  0.003411  0.013424  0.031831 -0.002283    NaN
# 시작_일     -0.002528  0.000243  0.003219  0.002246  0.004183  0.002337    NaN
# 종료_연도          NaN       NaN       NaN       NaN       NaN       NaN    NaN
# 종료_월     -0.012510 -0.012247  0.003402  0.012358  0.032187 -0.000195    NaN
# 종료_일     -0.000972 -0.000140  0.003444  0.000697  0.005312  0.004455    NaN
# 평일_주말_le -0.038667 -0.001742 -0.006473  0.039337 -0.015372 -0.026759    NaN
#
#               시작_월      시작_일  종료_연도      종료_월      종료_일  평일_주말_le
# 충전구분_le  -0.013578 -0.002528    NaN -0.012510 -0.000972 -0.038667
# 자치구_le   -0.012213  0.000243    NaN -0.012247 -0.000140 -0.001742
# 충전소명_le   0.003411  0.003219    NaN  0.003402  0.003444 -0.006473
# 충전기용량     0.013424  0.002246    NaN  0.012358  0.000697  0.039337
# 충전량       0.031831  0.004183    NaN  0.032187  0.005312 -0.015372
# 총_충전분    -0.002283  0.002337    NaN -0.000195  0.004455 -0.026759
# 시작_연도          NaN       NaN    NaN       NaN       NaN       NaN
# 시작_월      1.000000  0.019941    NaN  0.999805  0.022069  0.007566
# 시작_일      0.019941  1.000000    NaN  0.022194  0.972569 -0.021057
# 종료_연도          NaN       NaN    NaN       NaN       NaN       NaN
# 종료_월      0.999805  0.022194    NaN  1.000000  0.019772  0.007360
# 종료_일      0.022069  0.972569    NaN  0.019772  1.000000 -0.017960
# 평일_주말_le  0.007566 -0.021057    NaN  0.007360 -0.017960  1.000000

# %% [markdown]
# # 히트맵으로 확인
# plt.figure(figsize=(15, 8))
# sns.heatmap(data = df_one.corr(), annot=True)
# plt.title('시작, 종료 데이터, 충전시간, 충전분')
# plt.xticks(rotation=0)
# plt.show()

# %%
# 상관계수
df_two.corr()
# Out:
#            충전구분_le    자치구_le   충전소명_le     충전기용량       충전량     총_충전분  평일_주말_le
# 충전구분_le   1.000000  0.015451 -0.017482 -0.998213 -0.131878  0.388644 -0.038667
# 자치구_le    0.015451  1.000000  0.141213 -0.015252 -0.026620 -0.013089 -0.001742
# 충전소명_le  -0.017482  0.141213  1.000000  0.018442  0.002720 -0.014222 -0.006473
# 충전기용량    -0.998213 -0.015252  0.018442  1.000000  0.131360 -0.387731  0.039337
# 충전량      -0.131878 -0.026620  0.002720  0.131360  1.000000  0.148825 -0.015372
# 총_충전분     0.388644 -0.013089 -0.014222 -0.387731  0.148825  1.000000 -0.026759
# 평일_주말_le -0.038667 -0.001742 -0.006473  0.039337 -0.015372 -0.026759  1.000000

# %% [markdown]
# # 히트맵으로 확인
# plt.figure(figsize=(10, 4))
# sns.heatmap(data = df_two.corr(), annot=True)
# plt.title('충_전분')
# plt.xticks(rotation=0)
# plt.show()

# %% [markdown]
# 위 구조를 확인해본 결과 충전량에 대한 각 컬럼의 상관관계율이 낮은것으로 파악이 된다.<br>
# 그래서 충전량을 x축을 두고 각 컬럼의 scatter를 이용해서 데이터의 패턴을 파악을 해본다.

# %%
df_two['충전량'].unique()
# Out:
# array([5.000e-02, 1.310e+01, 4.756e+01, ..., 7.387e+01, 7.563e+01,
#        6.999e+01])

# %% [markdown]
# 자치구별 충전소 충전량을 통해서 걸리는 분을 예측,<br>
# 자치구별 충전소 걸린 시간을 통해서 충전량 예측  <- 뒷바침할 근거가 없다.<br><br>
#
# 새롭게 접근한 분석<br>
# 1. 특정 위치의 충전소의 데이터 추출
# 2. 급속충전, 완숙충전의 분포도 확인
# 3. 이용자의 급속일때 얼마나 충전, 완숙일때 얼마나 충전 확인
# 4. 특정 위치 충전소 이용자들이 어떤 유형으로 충전했고, 평균적으로 얼마나 충전했는지, 걸린시간도 확인
#
# 분석 후 어떤것을 예측하려고 하는지.<br><br>
#
# Self 주유소처럼 급속, 완속 선택 후 kWh 지정하면 걸리는 시간을 예측하는 것을 확인. 및 모델링.

# %% [markdown]
# ### 충전소 위치 지정

# %%
df.columns
# Out:
# Index(['충전구분', '충전소명', '주소', '충전기용량', '충전량', '충전시간', '충전분', '충전시작시각', '충전종료시각',
#        '시작_연도', '시작_월', '시작_일', '시작_시', '시작_분', '종료_연도', '종료_월', '종료_일',
#        '종료_시', '종료_분', '총_충전분', '평일_주말', '자치구', '자치구_le', '충전소명_le', '충전구분_le',
#        '평일_주말_le'],
#       dtype='object')

# %%
df['충전소명'].value_counts()
# Out:
# 충전소명
# 용산역 아이파크몰      12425
# 상암월드컵경기장       11224
# 뚝도충전소           6794
# 서울에너지공사 주차장     6614
# 리센츠 아파트         5110
#                ...
# 근상프리즘아파트           4
# 강북문화예술회관           3
# 서울영등포우체국           3
# 금나래체육문화센타          2
# SK렌터카 본사           2
# Name: count, Length: 604, dtype: int64

# %%
df['충전소명'].value_counts()
# Out:
# 충전소명
# 용산역 아이파크몰      12425
# 상암월드컵경기장       11224
# 뚝도충전소           6794
# 서울에너지공사 주차장     6614
# 리센츠 아파트         5110
#                ...
# 근상프리즘아파트           4
# 강북문화예술회관           3
# 서울영등포우체국           3
# 금나래체육문화센타          2
# SK렌터카 본사           2
# Name: count, Length: 604, dtype: int64

# %%
# 위에서 분포도에서 리센츠 아파트를 타겟으로 설정
target_df = df[df['충전소명'] == '용산역 아이파크몰']
target_df.head(3)
# Out:
#        충전구분       충전소명                                 주소  충전기용량    충전량  충전시간  \
# 378041   완속  용산역 아이파크몰  서울특별시 용산구 한강대로23길 55 (한강로3가, 용산역)      7   4.79     1
# 378044   급속  용산역 아이파크몰  서울특별시 용산구 한강대로23길 55 (한강로3가, 용산역)     50  51.39     1
# 378052   급속  용산역 아이파크몰  서울특별시 용산구 한강대로23길 55 (한강로3가, 용산역)     50   5.51     3
#
#         충전분               충전시작시각               충전종료시각  시작_연도  ...  종료_일  종료_시  \
# 378041   31  2021-01-01 16:40:52  2021-01-01 18:12:11   2021  ...     1    18
# 378044   20  2021-01-01 17:22:31  2021-01-01 18:43:20   2021  ...     1    18
# 378052   38  2021-01-01 16:27:44  2021-01-01 20:06:20   2021  ...     1    20
#
#         종료_분  총_충전분  평일_주말  자치구  자치구_le  충전소명_le  충전구분_le  평일_주말_le
# 378041    12     91     평일  용산구      20      465        1         1
# 378044    43     80     평일  용산구      20      465        0         1
# 378052     6    218     평일  용산구      20      465        0         1
#
# [3 rows x 26 columns]

# %%
# 충전소 명에서 데이터가 많은 상위 5개 추출
a = 1
for _ in df['충전소명'].value_counts()[:5].index:

    target_df = df[df['충전소명'] == _]

    col_two = ['충전구분_le','자치구_le', '충전소명_le', '충전기용량', '충전량', '총_충전분', '평일_주말_le']                                                                                      # 시작, 종료 데이터는 생략, 충전시간, 충전분 두개 컬럼 합친 총_충전분
    total_df = target_df[col_two]

    str = '0 : ' + le_type[0], ' 1 : ' + le_type[1]
    plt.figure(figsize=(5, 15))
    plt.subplot(5, 1, a)
    plt.hist(x=total_df['충전구분_le'])
    plt.xlabel(str)
    plt.xticks([0,1])

    plt.title(_)
    plt.show()
    a = a + 1

# %% [markdown]
# # 위에서 분포도에서 용산역 아이파크몰를 타겟으로 설정

# %%
# 수치화 진행된 컬럼 -> 데이터프레임으로 만들기
col_total = ['충전구분_le', '자치구_le', '충전소명_le','충전기용량', '충전량', '충전시간', '충전분', '총_충전분','시작_연도', '시작_월', '시작_일', '종료_연도', '종료_월', '종료_일', '평일_주말_le']
col_one = ['충전구분_le', '자치구_le', '충전소명_le','충전기용량', '충전량', '총_충전분', '시작_연도', '시작_월', '시작_일', '종료_연도', '종료_월', '종료_일', '평일_주말_le']       # 시작, 종료 데이터, 충전시간, 충전분 사용한 데이터
col_two = ['충전구분_le','자치구_le', '충전소명_le', '충전기용량', '충전량', '총_충전분', '평일_주말_le']                                                                                      # 시작, 종료 데이터는 생략, 충전시간, 충전분 두개 컬럼 합친 총_충전분

# %%
target_df = df[df['충전소명'] == '용산역 아이파크몰']

# %%
# 전체컬럼
total_df = target_df[col_total]
total_df.corr()
# Out:
#            충전구분_le  자치구_le  충전소명_le     충전기용량       충전량      충전시간       충전분  \
# 충전구분_le   1.000000     NaN      NaN -1.000000 -0.551654  0.454582 -0.004091
# 자치구_le         NaN     NaN      NaN       NaN       NaN       NaN       NaN
# 충전소명_le        NaN     NaN      NaN       NaN       NaN       NaN       NaN
# 충전기용량    -1.000000     NaN      NaN  1.000000  0.551654 -0.454582  0.004091
# 충전량      -0.551654     NaN      NaN  0.551654  1.000000  0.130329  0.085672
# 충전시간      0.454582     NaN      NaN -0.454582  0.130329  1.000000 -0.169172
# 충전분      -0.004091     NaN      NaN  0.004091  0.085672 -0.169172  1.000000
# 총_충전분     0.459535     NaN      NaN -0.459535  0.151612  0.974260  0.057359
# 시작_연도          NaN     NaN      NaN       NaN       NaN       NaN       NaN
# 시작_월     -0.015897     NaN      NaN  0.015897  0.062039  0.023466  0.006732
# 시작_일     -0.009083     NaN      NaN  0.009083  0.013667 -0.003081  0.008655
# 종료_연도          NaN     NaN      NaN       NaN       NaN       NaN       NaN
# 종료_월     -0.015751     NaN      NaN  0.015751  0.062022  0.023694  0.006666
# 종료_일     -0.009506     NaN      NaN  0.009506  0.014680 -0.001748  0.009564
# 평일_주말_le -0.061802     NaN      NaN  0.061802  0.018652  0.007362 -0.005751
#
#              총_충전분  시작_연도      시작_월      시작_일  종료_연도      종료_월      종료_일  \
# 충전구분_le   0.459535    NaN -0.015897 -0.009083    NaN -0.015751 -0.009506
# 자치구_le         NaN    NaN       NaN       NaN    NaN       NaN       NaN
# 충전소명_le        NaN    NaN       NaN       NaN    NaN       NaN       NaN
# 충전기용량    -0.459535    NaN  0.015897  0.009083    NaN  0.015751  0.009506
# 충전량       0.151612    NaN  0.062039  0.013667    NaN  0.062022  0.014680
# 충전시간      0.974260    NaN  0.023466 -0.003081    NaN  0.023694 -0.001748
# 충전분       0.057359    NaN  0.006732  0.008655    NaN  0.006666  0.009564
# 총_충전분     1.000000    NaN  0.025309 -0.001142    NaN  0.025525  0.000417
# 시작_연도          NaN    NaN       NaN       NaN    NaN       NaN       NaN
# 시작_월      0.025309    NaN  1.000000  0.025554    NaN  0.999980  0.026087
# 시작_일     -0.001142    NaN  0.025554  1.000000    NaN  0.025780  0.997223
# 종료_연도          NaN    NaN       NaN       NaN    NaN       NaN       NaN
# 종료_월      0.025525    NaN  0.999980  0.025780    NaN  1.000000  0.025851
# 종료_일      0.000417    NaN  0.026087  0.997223    NaN  0.025851  1.000000
# 평일_주말_le  0.006142    NaN  0.016904 -0.008132    NaN  0.017006 -0.009063
#
#           평일_주말_le
# 충전구분_le  -0.061802
# 자치구_le         NaN
# 충전소명_le        NaN
# 충전기용량     0.061802
# 충전량       0.018652
# 충전시간      0.007362
# 충전분      -0.005751
# 총_충전분     0.006142
# 시작_연도          NaN
# 시작_월      0.016904
# 시작_일     -0.008132
# 종료_연도          NaN
# 종료_월      0.017006
# 종료_일     -0.009063
# 평일_주말_le  1.000000

# %% [markdown]
# # 히트맵으로 확인
# plt.figure(figsize=(18, 8))
# sns.heatmap(data = total_df.corr(), annot=True)
# plt.title('전체 컬럼')
# plt.xticks(rotation=0)
# plt.show()

# %%
# col_one 컬럼
one_df = target_df[col_one]
one_df.corr()
# Out:
#            충전구분_le  자치구_le  충전소명_le     충전기용량       충전량     총_충전분  시작_연도  \
# 충전구분_le   1.000000     NaN      NaN -1.000000 -0.551654  0.459535    NaN
# 자치구_le         NaN     NaN      NaN       NaN       NaN       NaN    NaN
# 충전소명_le        NaN     NaN      NaN       NaN       NaN       NaN    NaN
# 충전기용량    -1.000000     NaN      NaN  1.000000  0.551654 -0.459535    NaN
# 충전량      -0.551654     NaN      NaN  0.551654  1.000000  0.151612    NaN
# 총_충전분     0.459535     NaN      NaN -0.459535  0.151612  1.000000    NaN
# 시작_연도          NaN     NaN      NaN       NaN       NaN       NaN    NaN
# 시작_월     -0.015897     NaN      NaN  0.015897  0.062039  0.025309    NaN
# 시작_일     -0.009083     NaN      NaN  0.009083  0.013667 -0.001142    NaN
# 종료_연도          NaN     NaN      NaN       NaN       NaN       NaN    NaN
# 종료_월     -0.015751     NaN      NaN  0.015751  0.062022  0.025525    NaN
# 종료_일     -0.009506     NaN      NaN  0.009506  0.014680  0.000417    NaN
# 평일_주말_le -0.061802     NaN      NaN  0.061802  0.018652  0.006142    NaN
#
#               시작_월      시작_일  종료_연도      종료_월      종료_일  평일_주말_le
# 충전구분_le  -0.015897 -0.009083    NaN -0.015751 -0.009506 -0.061802
# 자치구_le         NaN       NaN    NaN       NaN       NaN       NaN
# 충전소명_le        NaN       NaN    NaN       NaN       NaN       NaN
# 충전기용량     0.015897  0.009083    NaN  0.015751  0.009506  0.061802
# 충전량       0.062039  0.013667    NaN  0.062022  0.014680  0.018652
# 총_충전분     0.025309 -0.001142    NaN  0.025525  0.000417  0.006142
# 시작_연도          NaN       NaN    NaN       NaN       NaN       NaN
# 시작_월      1.000000  0.025554    NaN  0.999980  0.026087  0.016904
# 시작_일      0.025554  1.000000    NaN  0.025780  0.997223 -0.008132
# 종료_연도          NaN       NaN    NaN       NaN       NaN       NaN
# 종료_월      0.999980  0.025780    NaN  1.000000  0.025851  0.017006
# 종료_일      0.026087  0.997223    NaN  0.025851  1.000000 -0.009063
# 평일_주말_le  0.016904 -0.008132    NaN  0.017006 -0.009063  1.000000

# %%
one_df.head(2)
# Out:
#         충전구분_le  자치구_le  충전소명_le  충전기용량    충전량  총_충전분  시작_연도  시작_월  시작_일  \
# 378041        1      20      465      7   4.79     91   2021     1     1
# 378044        0      20      465     50  51.39     80   2021     1     1
#
#         종료_연도  종료_월  종료_일  평일_주말_le
# 378041   2021     1     1         1
# 378044   2021     1     1         1

# %% [markdown]
# # 히트맵으로 확인
# plt.figure(figsize=(18, 8))
# sns.heatmap(data = one_df.corr(), annot=True)
# plt.title('전체 컬럼')
# plt.xticks(rotation=0)
# plt.show()

# %%
# col_one 컬럼
two_df = target_df[col_two]
two_df.corr()
# Out:
#            충전구분_le  자치구_le  충전소명_le     충전기용량       충전량     총_충전분  평일_주말_le
# 충전구분_le   1.000000     NaN      NaN -1.000000 -0.551654  0.459535 -0.061802
# 자치구_le         NaN     NaN      NaN       NaN       NaN       NaN       NaN
# 충전소명_le        NaN     NaN      NaN       NaN       NaN       NaN       NaN
# 충전기용량    -1.000000     NaN      NaN  1.000000  0.551654 -0.459535  0.061802
# 충전량      -0.551654     NaN      NaN  0.551654  1.000000  0.151612  0.018652
# 총_충전분     0.459535     NaN      NaN -0.459535  0.151612  1.000000  0.006142
# 평일_주말_le -0.061802     NaN      NaN  0.061802  0.018652  0.006142  1.000000

# %%
two_df.head(2)
# Out:
#         충전구분_le  자치구_le  충전소명_le  충전기용량    충전량  총_충전분  평일_주말_le
# 378041        1      20      465      7   4.79     91         1
# 378044        0      20      465     50  51.39     80         1

# %% [markdown]
# # 히트맵으로 확인
# plt.figure(figsize=(10, 5))
# sns.heatmap(data = two_df.corr(), annot=True)
# plt.title('전체 컬럼')
# plt.xticks(rotation=0)
# plt.show()

# %%
plt.hist(x=two_df['평일_주말_le'])
plt.xlabel('1 평일 0 주말')
plt.xticks([0,1])
# Out:
# ([<matplotlib.axis.XTick at 0x1fca5bb7110>,
#   <matplotlib.axis.XTick at 0x1fca6415010>],
#  [Text(0, 0, '0'), Text(1, 0, '1')])

# %% [markdown]
# 위 그래프에서 평일, 주말 데이터들이 골고루 분포가 안되어있다는 것을 확인했습니다.
# <br>그래서 평일 데이터와 주말 데이터를 골고루 분포되게.. 행을 버립니다.

# %%
# 평일이면서 급속
work_zero = two_df[(two_df['평일_주말_le'] == 1 ) & (total_df['충전구분_le'] == 0) ]
work_zero.head(2)
# Out:
#         충전구분_le  자치구_le  충전소명_le  충전기용량    충전량  총_충전분  평일_주말_le
# 378044        0      20      465     50  51.39     80         1
# 378052        0      20      465     50   5.51    218         1

# %%
work_zero.shape
# Out:
# (4369, 7)

# %%
# 평일이면서 완속
work_one = two_df[(two_df['평일_주말_le'] == 1 ) & (total_df['충전구분_le'] == 1) ]
work_one.head(2)
# Out:
#         충전구분_le  자치구_le  충전소명_le  충전기용량   충전량  총_충전분  평일_주말_le
# 378041        1      20      465      7  4.79     91         1
# 378057        1      20      465      7  4.82     43         1

# %%
work_one.shape
# Out:
# (3649, 7)

# %%
# 주말이면서 급속
rest_zero = two_df[(two_df['평일_주말_le'] == 0 ) & (total_df['충전구분_le'] == 0) ]
rest_zero.shape
# Out:
# (2117, 7)

# %%
# 주말이면서 완속
rest_one = two_df[(two_df['평일_주말_le'] == 0 ) & (total_df['충전구분_le'] == 1) ]
rest_one.shape
# Out:
# (2290, 7)

# %% [markdown]
# 평일 데이터는 : 8018<br>
# 주말 데이터는 : 4407<br>
#
# 평일 급속, 평일 완속 데이터를 각각 1805개씩 삭제를 하면 된다.

# %%
work_zero.index[:1805]
# Out:
# Index([378044, 378052, 378053, 378063, 378078, 378086, 378091, 378098, 378112,
#        378114,
#        ...
#        405555, 405558, 405564, 405585, 405613, 405614, 405630, 405632, 405634,
#        405646],
#       dtype='int64', length=1805)

# %%
work_zero_index = work_zero.index[:1805].to_list()
work_zero_index
# Out:
# [378044,
#  378052,
#  378053,
#  378063,
#  378078,
#  378086,
#  378091,
#  378098,
#  378112,
#  378114,
#  378117,
#  378119,
#  378124,
#  378126,
#  378127,
#  378139,
#  378401,
#  378409,
#  378411,
#  378428,
#  378429,
#  378441,
#  378446,
#  378454,
#  378469,
#  378491,
#  378499,
#  378512,
#  378525,
#  378546,
#  378554,
#  378558,
#  378564,
#  378587,
#  378597,
#  378606,
#  378627,
#  378639,
#  378649,
#  378652,
#  378656,
#  378664,
#  378687,
#  378689,
#  378697,
#  378700,
#  378705,
#  378708,
#  378756,
#  378757,
#  378808,
#  378828,
#  378838,
#  378839,
#  378854,
#  378862,
#  378869,
#  378896,
#  378898,
#  378938,
#  378939,
#  378952,
#  378953,
#  378961,
#  378964,
#  378967,
#  378970,
#  378984,
#  378987,
#  378991,
#  379002,
#  379004,
#  379006,
#  379010,
#  379012,
#  379017,
#  379020,
#  379024,
#  379033,
#  379041,
#  379051,
#  379052,
#  379072,
#  379087,
#  379093,
#  379095,
#  379096,
#  379097,
#  379098,
#  379102,
#  379105,
#  379111,
#  379118,
#  379126,
#  379132,
#  379139,
#  379142,
#  379146,
#  379149,
#  379153,
#  379156,
#  379168,
#  379176,
#  379177,
#  379179,
#  379181,
#  379185,
#  379190,
#  379202,
#  379204,
#  379205,
#  379526,
#  379548,
#  379564,
#  379566,
#  379567,
#  379568,
#  379578,
#  379592,
#  379616,
#  379626,
#  379627,
#  379638,
#  379644,
#  379678,
#  379682,
#  379694,
#  379697,
#  379708,
#  379723,
#  379734,
#  379739,
#  379741,
#  379761,
#  379773,
#  379778,
#  379780,
#  379790,
#  379793,
#  379808,
#  379809,
#  379810,
#  379822,
#  379824,
#  379838,
#  379865,
#  379866,
#  379883,
#  379886,
#  379908,
#  379917,
#  379920,
#  379923,
#  379926,
#  379932,
#  379940,
#  379959,
#  379969,
#  379992,
#  380002,
#  380021,
#  380024,
#  380029,
#  380058,
#  380071,
#  380091,
#  380093,
#  380109,
#  380112,
#  380135,
#  380137,
#  380138,
#  380148,
#  380161,
#  380180,
#  380184,
#  380204,
#  380207,
#  380213,
#  380220,
#  380244,
#  380248,
#  380264,
#  380268,
#  380277,
#  380609,
#  380616,
#  380620,
#  380634,
#  380635,
#  380645,
#  380646,
#  380647,
#  380662,
#  380670,
#  380676,
#  380681,
#  380693,
#  380703,
#  380708,
#  380713,
#  380720,
#  380727,
#  380744,
#  380746,
#  380752,
#  380754,
#  380755,
#  380758,
#  380779,
#  380780,
#  380791,
#  380794,
#  380808,
#  380851,
#  380853,
#  380854,
#  380886,
#  380887,
#  380891,
#  380894,
#  380922,
#  380938,
#  380954,
#  380971,
#  380974,
#  380986,
#  380990,
#  380998,
#  381000,
#  381012,
#  381013,
#  381028,
#  381031,
#  381034,
#  381037,
#  381041,
#  381051,
#  381055,
#  381076,
#  381080,
#  381090,
#  381101,
#  381102,
#  381108,
#  381114,
#  381115,
#  381120,
#  381129,
#  381145,
#  381146,
#  381177,
#  381194,
#  381198,
#  381203,
#  381210,
#  381212,
#  381217,
#  381222,
#  381224,
#  381226,
#  381229,
#  381232,
#  381246,
#  381254,
#  381260,
#  381283,
#  381325,
#  381346,
#  381357,
#  381359,
#  381667,
#  381683,
#  381684,
#  381688,
#  381692,
#  381693,
#  381699,
#  381713,
#  381723,
#  381729,
#  381730,
#  381731,
#  381732,
#  381746,
#  381747,
#  381764,
#  381772,
#  381795,
#  381827,
#  381842,
#  381864,
#  381867,
#  381869,
#  381875,
#  381901,
#  381905,
#  381950,
#  381975,
#  381984,
#  381985,
#  381994,
#  382007,
#  382010,
#  382061,
#  382071,
#  382087,
#  382097,
#  382099,
#  382111,
#  382121,
#  382134,
#  382135,
#  382140,
#  382163,
#  382173,
#  382178,
#  382188,
#  382189,
#  382205,
#  382213,
#  382214,
#  382217,
#  382230,
#  382238,
#  382242,
#  382255,
#  382256,
#  382257,
#  382265,
#  382282,
#  382288,
#  382305,
#  382306,
#  382310,
#  382315,
#  382327,
#  382332,
#  382345,
#  382354,
#  382355,
#  382358,
#  382376,
#  382388,
#  382397,
#  382411,
#  382413,
#  382418,
#  382421,
#  382445,
#  382793,
#  382803,
#  382807,
#  382811,
#  382816,
#  382823,
#  382826,
#  382845,
#  382869,
#  382887,
#  382889,
#  382899,
#  382902,
#  382909,
#  382935,
#  382936,
#  382938,
#  382944,
#  382947,
#  382950,
#  382951,
#  382952,
#  382963,
#  382967,
#  382988,
#  382989,
#  382990,
#  382992,
#  382999,
#  383000,
#  383010,
#  383025,
#  383032,
#  383033,
#  383067,
#  383073,
#  383112,
#  383113,
#  383116,
#  383126,
#  383131,
#  383141,
#  383156,
#  383181,
#  383225,
#  383234,
#  383255,
#  383260,
#  383267,
#  383273,
#  383297,
#  383310,
#  383319,
#  383331,
#  383345,
#  383361,
#  383370,
#  383375,
#  383377,
#  386841,
#  386853,
#  386865,
#  386876,
#  386877,
#  386881,
#  387188,
#  387197,
#  387230,
#  387237,
#  387241,
#  387250,
#  387260,
#  387277,
#  387287,
#  387288,
#  387294,
#  387298,
#  387302,
#  387327,
#  387329,
#  387333,
#  387349,
#  387362,
#  387365,
#  387374,
#  387375,
#  387385,
#  387406,
#  387408,
#  387409,
#  387442,
#  387475,
#  387479,
#  387487,
#  387508,
#  387513,
#  387516,
#  387530,
#  387537,
#  387539,
#  387545,
#  387550,
#  387558,
#  387570,
#  387583,
#  387585,
#  387601,
#  387613,
#  387641,
#  387645,
#  387671,
#  387675,
#  387677,
#  387698,
#  387716,
#  387734,
#  387772,
#  387779,
#  387780,
#  387789,
#  387791,
#  387793,
#  387801,
#  387838,
#  387855,
#  387864,
#  387888,
#  387891,
#  387892,
#  387901,
#  387930,
#  388002,
#  388275,
#  388276,
#  388287,
#  388296,
#  388303,
#  388326,
#  388357,
#  388360,
#  388378,
#  388380,
#  388402,
#  388403,
#  388417,
#  388428,
#  388465,
#  388474,
#  388480,
#  388492,
#  388503,
#  388520,
#  388546,
#  388574,
#  388576,
#  388596,
#  388607,
#  388623,
#  388627,
#  388632,
#  388640,
#  388644,
#  388645,
#  388648,
#  388660,
#  388722,
#  388728,
#  388738,
#  388748,
#  388877,
#  388882,
#  388889,
#  388892,
#  388908,
#  388910,
#  388913,
#  388920,
#  388933,
#  388934,
#  388956,
#  388992,
#  389005,
#  389013,
#  389027,
#  389028,
#  389047,
#  389049,
#  389056,
#  389407,
#  389420,
#  389443,
#  389470,
#  389472,
#  389476,
#  389490,
#  389509,
#  389520,
#  389524,
#  389542,
#  389543,
#  389568,
#  389571,
#  389586,
#  389593,
#  389612,
#  389615,
#  389617,
#  389619,
#  389658,
#  389675,
#  389690,
#  389716,
#  389728,
#  389743,
#  389757,
#  389763,
#  389773,
#  389786,
#  389787,
#  389789,
#  389795,
#  389814,
#  389833,
#  389861,
#  389867,
#  389898,
#  389923,
#  389955,
#  389956,
#  389962,
#  389973,
#  389979,
#  389980,
#  389986,
#  389994,
#  390004,
#  390011,
#  390047,
#  390054,
#  390064,
#  390076,
#  390084,
#  390085,
#  390097,
#  390099,
#  390114,
#  390419,
#  390427,
#  390452,
#  390456,
#  390484,
#  390513,
#  390521,
#  390529,
#  390533,
#  390549,
#  390562,
#  390598,
#  390604,
#  390618,
#  390631,
#  390647,
#  390695,
#  390708,
#  390714,
#  390723,
#  390730,
#  390754,
#  390755,
#  390765,
#  390770,
#  390799,
#  390836,
#  390893,
#  390898,
#  390914,
#  390927,
#  390930,
#  390940,
#  390962,
#  390968,
#  390990,
#  391002,
#  391023,
#  391030,
#  391037,
#  391045,
#  391060,
#  391082,
#  391083,
#  391088,
#  391092,
#  391095,
#  391102,
#  391149,
#  391468,
#  391475,
#  391491,
#  391496,
#  391515,
#  391543,
#  391562,
#  391584,
#  391588,
#  391611,
#  391613,
#  391615,
#  391657,
#  391666,
#  391703,
#  391719,
#  391721,
#  391725,
#  391729,
#  391735,
#  391747,
#  391754,
#  391770,
#  391774,
#  391775,
#  391776,
#  391778,
#  391781,
#  391783,
#  391786,
#  391788,
#  391791,
#  391797,
#  391813,
#  391814,
#  391819,
#  391833,
#  391848,
#  391858,
#  391868,
#  391869,
#  391870,
#  391895,
#  391896,
#  391934,
#  391942,
#  391955,
#  391957,
#  391969,
#  391971,
#  392005,
#  392008,
#  392010,
#  392027,
#  392031,
#  392059,
#  392136,
#  392141,
#  392151,
#  392156,
#  392162,
#  392183,
#  392542,
#  392546,
#  392570,
#  392578,
#  392580,
#  392602,
#  392611,
#  392629,
#  392647,
#  392675,
#  392679,
#  392692,
#  392699,
#  392746,
#  392751,
#  392761,
#  392776,
#  392781,
#  392790,
#  392795,
#  392805,
#  392824,
#  392844,
#  392846,
#  392850,
#  392896,
#  392901,
#  392908,
#  392937,
#  392938,
#  393002,
#  393009,
#  393044,
#  393060,
#  393066,
#  393068,
#  393079,
#  393081,
#  393099,
#  ...]

# %%
# 평일 급속 데이터 1805개 삭제
two_df.drop(index=work_zero_index, inplace=True)
two_df.shape
# Out:
# C:\Users\Jik\AppData\Local\Temp\ipykernel_9620\2882731809.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   two_df.drop(index=work_zero_index, inplace=True)
# (10620, 7)

# %%
work_one_index = work_one.index[:1805].to_list()
work_one_index
# Out:
# [378041,
#  378057,
#  378059,
#  378077,
#  378092,
#  378093,
#  378101,
#  378128,
#  378130,
#  378400,
#  378402,
#  378410,
#  378424,
#  378427,
#  378462,
#  378477,
#  378478,
#  378500,
#  378527,
#  378555,
#  378562,
#  378603,
#  378608,
#  378610,
#  378633,
#  378638,
#  378693,
#  378701,
#  378703,
#  378721,
#  378723,
#  378739,
#  378749,
#  378752,
#  378760,
#  378778,
#  378784,
#  378788,
#  378789,
#  378795,
#  378802,
#  378803,
#  378816,
#  378846,
#  378856,
#  378911,
#  378951,
#  378955,
#  378958,
#  378992,
#  378996,
#  379038,
#  379040,
#  379101,
#  379127,
#  379137,
#  379157,
#  379198,
#  379211,
#  379527,
#  379533,
#  379535,
#  379546,
#  379576,
#  379581,
#  379602,
#  379610,
#  379630,
#  379631,
#  379655,
#  379681,
#  379706,
#  379726,
#  379787,
#  379803,
#  379811,
#  379818,
#  379832,
#  379833,
#  379856,
#  379867,
#  379891,
#  379895,
#  379915,
#  379916,
#  379968,
#  379975,
#  379976,
#  379984,
#  380004,
#  380008,
#  380009,
#  380015,
#  380023,
#  380026,
#  380055,
#  380061,
#  380068,
#  380081,
#  380086,
#  380097,
#  380124,
#  380133,
#  380136,
#  380139,
#  380142,
#  380144,
#  380160,
#  380165,
#  380198,
#  380212,
#  380608,
#  380636,
#  380666,
#  380672,
#  380687,
#  380714,
#  380717,
#  380721,
#  380723,
#  380731,
#  380732,
#  380733,
#  380740,
#  380743,
#  380793,
#  380800,
#  380803,
#  380820,
#  380822,
#  380824,
#  380827,
#  380831,
#  380865,
#  380876,
#  380883,
#  380907,
#  380934,
#  380936,
#  380950,
#  380962,
#  380968,
#  381007,
#  381014,
#  381039,
#  381050,
#  381053,
#  381077,
#  381079,
#  381088,
#  381096,
#  381099,
#  381105,
#  381140,
#  381144,
#  381151,
#  381225,
#  381228,
#  381235,
#  381244,
#  381256,
#  381300,
#  381309,
#  381321,
#  381335,
#  381340,
#  381351,
#  381366,
#  381678,
#  381679,
#  381681,
#  381686,
#  381695,
#  381709,
#  381734,
#  381736,
#  381741,
#  381751,
#  381780,
#  381789,
#  381794,
#  381805,
#  381808,
#  381821,
#  381826,
#  381832,
#  381836,
#  381858,
#  381879,
#  381891,
#  381893,
#  381907,
#  381908,
#  381926,
#  381930,
#  381931,
#  381938,
#  381941,
#  381946,
#  381970,
#  381989,
#  382022,
#  382037,
#  382040,
#  382048,
#  382052,
#  382054,
#  382090,
#  382098,
#  382104,
#  382108,
#  382115,
#  382138,
#  382141,
#  382147,
#  382151,
#  382156,
#  382157,
#  382167,
#  382183,
#  382196,
#  382197,
#  382204,
#  382221,
#  382226,
#  382231,
#  382239,
#  382243,
#  382244,
#  382248,
#  382260,
#  382292,
#  382347,
#  382414,
#  382424,
#  382451,
#  382452,
#  382459,
#  382772,
#  382773,
#  382809,
#  382814,
#  382822,
#  382908,
#  382919,
#  382920,
#  382922,
#  382925,
#  382934,
#  382966,
#  382970,
#  382977,
#  383006,
#  383044,
#  383048,
#  383057,
#  383065,
#  383075,
#  383093,
#  383130,
#  383136,
#  383146,
#  383168,
#  383177,
#  383193,
#  383199,
#  383212,
#  383217,
#  383242,
#  383275,
#  383280,
#  383287,
#  383317,
#  383344,
#  383371,
#  383380,
#  383396,
#  383402,
#  383427,
#  383434,
#  383451,
#  383460,
#  383466,
#  383467,
#  383470,
#  383484,
#  383502,
#  383506,
#  383529,
#  383534,
#  383548,
#  383693,
#  383880,
#  383882,
#  383895,
#  383896,
#  383897,
#  383958,
#  383989,
#  384012,
#  384047,
#  384058,
#  384070,
#  384072,
#  384083,
#  384111,
#  384136,
#  384140,
#  384152,
#  384243,
#  384256,
#  384267,
#  384269,
#  384284,
#  384292,
#  384296,
#  384312,
#  384329,
#  384337,
#  384356,
#  384359,
#  384385,
#  384393,
#  384429,
#  384430,
#  384431,
#  384435,
#  384468,
#  384470,
#  384489,
#  384510,
#  384513,
#  384518,
#  384520,
#  384528,
#  384534,
#  384537,
#  384547,
#  384553,
#  384554,
#  384571,
#  384578,
#  384582,
#  384587,
#  384593,
#  384609,
#  384612,
#  384613,
#  384615,
#  384618,
#  384620,
#  384627,
#  384632,
#  384635,
#  384647,
#  384648,
#  384654,
#  384936,
#  384939,
#  384952,
#  384973,
#  384984,
#  384991,
#  385036,
#  385037,
#  385053,
#  385067,
#  385076,
#  385082,
#  385090,
#  385097,
#  385106,
#  385107,
#  385165,
#  385185,
#  385247,
#  385258,
#  385302,
#  385304,
#  385341,
#  385369,
#  385381,
#  385382,
#  385393,
#  385435,
#  385436,
#  385443,
#  385462,
#  385487,
#  385490,
#  385500,
#  385514,
#  385521,
#  385524,
#  385525,
#  385530,
#  385532,
#  385541,
#  385546,
#  385577,
#  385586,
#  385594,
#  385608,
#  385616,
#  385623,
#  385624,
#  385649,
#  385663,
#  385686,
#  385700,
#  385719,
#  385730,
#  385735,
#  385748,
#  385751,
#  385752,
#  385755,
#  386099,
#  386101,
#  386102,
#  386121,
#  386129,
#  386165,
#  386195,
#  386203,
#  386206,
#  386226,
#  386245,
#  386270,
#  386279,
#  386303,
#  386306,
#  386311,
#  386318,
#  386320,
#  386322,
#  386325,
#  386328,
#  386343,
#  386353,
#  386363,
#  386364,
#  386396,
#  386403,
#  386420,
#  386426,
#  386472,
#  386477,
#  386478,
#  386496,
#  386514,
#  386515,
#  386529,
#  386531,
#  386534,
#  386536,
#  386549,
#  386566,
#  386600,
#  386648,
#  386653,
#  386662,
#  386677,
#  386688,
#  386707,
#  386729,
#  386730,
#  386733,
#  386735,
#  386739,
#  386741,
#  386752,
#  386754,
#  386755,
#  386768,
#  386772,
#  386783,
#  386792,
#  386805,
#  386813,
#  386816,
#  386844,
#  386866,
#  386869,
#  386872,
#  386880,
#  387186,
#  387190,
#  387202,
#  387218,
#  387219,
#  387220,
#  387223,
#  387225,
#  387233,
#  387234,
#  387247,
#  387251,
#  387253,
#  387254,
#  387261,
#  387263,
#  387266,
#  387285,
#  387306,
#  387310,
#  387312,
#  387313,
#  387317,
#  387354,
#  387360,
#  387367,
#  387376,
#  387398,
#  387416,
#  387423,
#  387424,
#  387462,
#  387498,
#  387503,
#  387504,
#  387507,
#  387515,
#  387551,
#  387554,
#  387561,
#  387580,
#  387589,
#  387596,
#  387603,
#  387604,
#  387649,
#  387667,
#  387676,
#  387700,
#  387703,
#  387705,
#  387707,
#  387710,
#  387728,
#  387756,
#  387768,
#  387771,
#  387775,
#  387777,
#  387798,
#  387811,
#  387833,
#  387836,
#  387869,
#  387879,
#  387907,
#  387919,
#  387926,
#  387928,
#  387935,
#  388024,
#  388273,
#  388282,
#  388286,
#  388288,
#  388310,
#  388313,
#  388325,
#  388327,
#  388334,
#  388336,
#  388391,
#  388418,
#  388420,
#  388434,
#  388439,
#  388455,
#  388464,
#  388467,
#  388507,
#  388512,
#  388518,
#  388531,
#  388553,
#  388557,
#  388562,
#  388600,
#  388612,
#  388622,
#  388625,
#  388663,
#  388670,
#  388673,
#  388699,
#  388707,
#  388715,
#  388718,
#  388723,
#  388730,
#  388733,
#  388742,
#  388760,
#  388792,
#  388793,
#  388805,
#  388807,
#  388828,
#  388830,
#  388838,
#  388847,
#  388867,
#  388870,
#  388879,
#  388897,
#  388921,
#  388942,
#  388948,
#  388968,
#  388973,
#  388979,
#  389000,
#  389009,
#  389062,
#  389110,
#  389414,
#  389417,
#  389435,
#  389468,
#  389484,
#  389514,
#  389515,
#  389527,
#  389530,
#  389533,
#  389557,
#  389574,
#  389583,
#  389591,
#  389624,
#  389639,
#  389649,
#  389673,
#  389756,
#  389791,
#  389800,
#  389808,
#  389819,
#  389823,
#  389825,
#  389858,
#  389863,
#  389869,
#  389887,
#  389889,
#  389903,
#  389904,
#  389917,
#  389944,
#  389948,
#  389989,
#  390001,
#  390013,
#  390032,
#  390051,
#  390060,
#  390087,
#  390089,
#  390098,
#  390107,
#  390121,
#  390417,
#  390450,
#  390493,
#  390495,
#  390525,
#  390554,
#  390572,
#  390573,
#  390603,
#  390606,
#  390629,
#  390638,
#  390650,
#  390692,
#  390702,
#  390703,
#  390710,
#  390744,
#  390753,
#  390764,
#  390778,
#  390796,
#  390801,
#  390805,
#  390827,
#  390829,
#  390852,
#  390857,
#  390873,
#  390901,
#  390903,
#  390906,
#  390907,
#  390910,
#  390936,
#  390937,
#  390943,
#  390953,
#  390979,
#  390981,
#  390987,
#  390988,
#  391007,
#  391016,
#  391021,
#  391031,
#  391056,
#  391072,
#  391115,
#  391130,
#  391146,
#  391148,
#  391218,
#  391270,
#  391458,
#  391476,
#  391481,
#  391497,
#  391498,
#  391511,
#  391534,
#  391544,
#  391553,
#  391554,
#  391555,
#  391556,
#  391557,
#  391561,
#  391565,
#  391567,
#  391571,
#  391618,
#  391622,
#  391625,
#  391626,
#  391630,
#  391644,
#  391652,
#  391662,
#  391675,
#  391688,
#  391700,
#  391704,
#  391718,
#  391724,
#  391763,
#  391764,
#  391779,
#  391780,
#  391782,
#  391785,
#  391800,
#  391802,
#  391837,
#  391887,
#  391925,
#  391939,
#  391940,
#  391945,
#  391954,
#  391965,
#  391970,
#  391981,
#  392037,
#  392042,
#  392049,
#  392061,
#  392076,
#  392084,
#  392104,
#  392147,
#  392199,
#  392531,
#  392563,
#  392574,
#  392594,
#  392596,
#  392598,
#  392606,
#  392628,
#  392635,
#  392657,
#  392688,
#  392690,
#  392714,
#  392718,
#  392724,
#  392757,
#  392759,
#  392783,
#  392793,
#  392794,
#  392796,
#  392807,
#  392813,
#  392855,
#  392880,
#  392884,
#  392893,
#  392899,
#  392919,
#  392926,
#  392936,
#  392976,
#  392987,
#  393034,
#  393037,
#  393050,
#  393051,
#  393065,
#  393072,
#  393076,
#  393082,
#  393085,
#  393095,
#  393097,
#  393113,
#  393140,
#  393169,
#  393184,
#  393186,
#  393199,
#  393212,
#  393219,
#  393222,
#  393223,
#  393226,
#  393230,
#  393254,
#  393259,
#  393262,
#  393265,
#  393295,
#  393303,
#  393307,
#  393357,
#  393358,
#  393423,
#  393468,
#  393534,
#  393720,
#  393733,
#  393742,
#  393750,
#  393751,
#  393765,
#  393787,
#  393808,
#  393812,
#  393821,
#  393827,
#  393832,
#  393837,
#  393851,
#  393873,
#  393874,
#  393876,
#  393891,
#  393905,
#  393907,
#  393915,
#  393952,
#  393957,
#  393961,
#  393972,
#  393976,
#  393986,
#  393994,
#  394006,
#  394022,
#  394037,
#  394064,
#  394074,
#  394098,
#  394106,
#  394122,
#  394142,
#  394149,
#  394158,
#  394210,
#  394212,
#  394222,
#  394244,
#  394245,
#  394261,
#  394263,
#  394265,
#  394311,
#  394317,
#  394323,
#  394336,
#  394359,
#  394366,
#  394372,
#  394380,
#  394409,
#  394427,
#  394449,
#  394778,
#  394789,
#  394790,
#  394807,
#  394821,
#  394834,
#  394853,
#  394869,
#  394882,
#  394883,
#  394898,
#  394921,
#  394932,
#  394936,
#  394942,
#  394952,
#  394959,
#  394967,
#  394980,
#  394983,
#  394988,
#  394994,
#  395012,
#  395015,
#  395029,
#  395081,
#  395091,
#  395107,
#  395108,
#  395113,
#  395164,
#  395212,
#  395235,
#  395254,
#  395298,
#  395312,
#  395318,
#  395335,
#  395351,
#  395404,
#  395405,
#  395414,
#  395416,
#  395445,
#  395449,
#  395484,
#  395486,
#  395886,
#  395888,
#  395919,
#  395921,
#  395922,
#  395943,
#  395950,
#  395967,
#  396037,
#  396064,
#  396065,
#  396072,
#  396105,
#  396123,
#  396162,
#  396174,
#  396182,
#  396191,
#  396212,
#  396222,
#  396235,
#  396255,
#  396258,
#  396284,
#  396286,
#  396297,
#  396307,
#  396327,
#  396331,
#  396355,
#  396365,
#  396370,
#  396373,
#  396384,
#  396385,
#  396393,
#  396415,
#  396448,
#  396457,
#  396461,
#  396479,
#  396510,
#  396539,
#  396547,
#  396553,
#  396569,
#  396570,
#  396587,
#  396590,
#  ...]

# %%
# 평일 완속 데이터 1805개 삭제
two_df.drop(index=work_one_index, inplace=True)
two_df.shape
# Out:
# C:\Users\Jik\AppData\Local\Temp\ipykernel_9620\4078207041.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   two_df.drop(index=work_one_index, inplace=True)
# (8815, 7)

# %%
plt.hist(x=two_df['평일_주말_le'])
plt.xlabel('1 평일 0 주말')
plt.xticks([0,1])
# Out:
# ([<matplotlib.axis.XTick at 0x1fca6c39150>,
#   <matplotlib.axis.XTick at 0x1fca6046890>],
#  [Text(0, 0, '0'), Text(1, 0, '1')])

# %% [markdown]
# 위 분포도를 확인해보면 균등하게 되어있는 것을 확인했다.

# %%
# 급속
fast = total_df[total_df['충전구분_le'] == 0]
fast.head()
# Out:
#         충전구분_le  자치구_le  충전소명_le  충전기용량    충전량  충전시간  충전분  총_충전분  시작_연도  시작_월  \
# 378044        0      20      465     50  51.39     1   20     80   2021     1
# 378052        0      20      465     50   5.51     3   38    218   2021     1
# 378053        0      20      465     50  19.54     2    6    126   2021     1
# 378063        0      20      465     50  10.00     0   28     28   2021     1
# 378078        0      20      465     50  30.45     0   43     43   2021     1
#
#         시작_일  종료_연도  종료_월  종료_일  평일_주말_le
# 378044     1   2021     1     1         1
# 378052     1   2021     1     1         1
# 378053     1   2021     1     1         1
# 378063     1   2021     1     1         1
# 378078     1   2021     1     1         1

# %%
# 완속
slow= total_df[total_df['충전구분_le'] == 1]
slow.head()
# Out:
#         충전구분_le  자치구_le  충전소명_le  충전기용량   충전량  충전시간  충전분  총_충전분  시작_연도  시작_월  \
# 378041        1      20      465      7  4.79     1   31     91   2021     1
# 378057        1      20      465      7  4.82     0   43     43   2021     1
# 378059        1      20      465      7  1.35     0   24     24   2021     1
# 378077        1      20      465      7  7.83     1   11     71   2021     1
# 378092        1      20      465      7  1.24     0   21     21   2021     1
#
#         시작_일  종료_연도  종료_월  종료_일  평일_주말_le
# 378041     1   2021     1     1         1
# 378057     1   2021     1     1         1
# 378059     1   2021     1     1         1
# 378077     1   2021     1     1         1
# 378092     1   2021     1     1         1

# %%
print('급속 이용자의 충전량 : ', fast['충전량'].mean(), '\n충전_분 : ', fast['총_충전분'].mean())
# Out:
# 급속 이용자의 충전량 :  27.976036077705828
# 충전_분 :  51.43015726179463

# %%
print('완속 이용자의 충전량 : ', slow['충전량'].mean(), '\n충전_분 : ', slow['총_충전분'].mean())
# Out:
# 완속 이용자의 충전량 :  10.103123421451423
# 충전_분 :  120.37632598080485

# %%
fast_one = two_df[(two_df['충전구분_le'] == 0) & (two_df['평일_주말_le'] == 1 )]
print('평일 급속', '\n충전량 평균 : ', fast_one['충전량'].mean(), '\n총_충전분 평균', fast_one['총_충전분'].mean())

fast_zero = two_df[(two_df['충전구분_le'] == 0) & (two_df['평일_주말_le'] == 0 )]
print('주말 급속', '\n충전량 평균 : ', fast_zero['충전량'].mean(), '\n총_충전분 평균', fast_zero['총_충전분'].mean())

slow_one = two_df[(two_df['충전구분_le'] == 1) & (two_df['평일_주말_le'] == 1 )]
print('평일 완속', '\n충전량 평균 : ', slow_one['충전량'].mean(), '\n총_충전분 평균', slow_one['총_충전분'].mean())

slow_zero = two_df[(two_df['충전구분_le'] == 1) & (two_df['평일_주말_le'] == 0 )]
print('주말 완속', '\n충전량 평균 : ', slow_zero['충전량'].mean(), '\n총_충전분 평균', slow_zero['총_충전분'].mean())
# Out:
# 평일 급속
# 충전량 평균 :  28.24693057722309
# 총_충전분 평균 50.64976599063962
# 주말 급속
# 충전량 평균 :  29.361511572980636
# 총_충전분 평균 53.75814832309872
# 평일 완속
# 충전량 평균 :  10.943850325379609
# 총_충전분 평균 128.89045553145337
# 주말 완속
# 충전량 평균 :  9.470991266375545
# 총_충전분 평균 111.50436681222708

# %% [markdown]
# ### 결과<br>
# 용산역 아이파크몰는 급속 이용자 < 완속 이용자 입니다.<br>
#
# 급속 이용자<br>
#
# - 평일 급속<br>
#     - 충전량 평균 : 28.24693057722309 <br>
#     - 총_충전분 평균 : 50.64976599063962<br>
# - 주말 급속<br>
#     - 충전량 평균 : 29.361511572980636<br>
#     - 총_충전분 평균 : 53.75814832309872<br>
# - 평일 완속<br>
#     - 충전량 평균 : 10.943850325379609<br>
#     - 총_충전분 평균 : 128.89045553145337<br>
# - 주말 완속<br>
#     - 충전량 평균 : 9.470991266375545<br>
#     - 총_충전분 평균 : 111.50436681222708<br>
#
#
# 이를 통해서 급속 이용자, 완속이용자가 셀프 주유소처럼 kWh(킬로와트시)로 지정하면 걸리는 총 분을 예측하는 모델설계.<br>

# %% [markdown]
# ## 셀프주유소처럼 kWh 지정후 걸리는 시간 예측 모델
#
# 사용할 모델<br>
#     - 로지스틱 회귀<br>
#     - 결정트리<br>
#     - 잠시 대기!@#!@#!@#!@#!@#!@#! 서포트 백터<br>

# %%
# 데이터 분리
from sklearn.model_selection import train_test_split

# 모델 선언
from sklearn.linear_model import LogisticRegression          # 로지스틱 회귀
from sklearn.tree import DecisionTreeRegressor

# 표준화 및 정규화
from sklearn.preprocessing import StandardScaler            # 표준화
from sklearn.preprocessing import MinMaxScaler              # 정규화

# 평가
from sklearn.metrics import accuracy_score

# 앙상블 모델

# %%
# 사용할 데이터 프레임은
two_df.head(3)
# Out:
#         충전구분_le  자치구_le  충전소명_le  충전기용량    충전량  총_충전분  평일_주말_le
# 378143        1      20      465      7  11.19    102         0
# 378149        0      20      465     50  15.97     30         0
# 378160        1      20      465      7  11.05    205         0

# %%
#sns.kdeplot(data=two_df)
#plt.show()

# %%
select_col = ['충전구분_le', '자치구_le', '충전소명_le', '충전기용량', '충전량', '총_충전분', '평일_주말_le']
two_df[select_col].head(2)
# Out:
#         충전구분_le  자치구_le  충전소명_le  충전기용량    충전량  총_충전분  평일_주말_le
# 378143        1      20      465      7  11.19    102         0
# 378149        0      20      465     50  15.97     30         0

# %%
target = two_df['총_충전분']
#target.to_numpy().reshape(-1,1)

# %%
train_input, test_input, train_target, test_target = train_test_split(
    two_df[select_col], target, random_state=42, train_size=0.8
)

# %%
# 모델 학습을 진행 중에 충전량 컬럼이 정규화 필요하다는 에러가 발생!! 표준화 진행.
ss = StandardScaler()
train_input_ss = ss.fit_transform(train_input)
test_input_ss = ss.fit_transform(test_input)

# %%
mm = MinMaxScaler()
train_input_mm = mm.fit_transform(train_input)
test_input_mm = mm.fit_transform(test_input)

# %% [markdown]
# ### 결정트리

# %% [markdown]
# 아침에 해야할것 결정트리 그리드 서치 후 최적의 하이퍼 파라미터구해서 학습시키기.

# %%
from sklearn.tree import DecisionTreeRegressor

dtc = DecisionTreeRegressor()
dtc.fit(train_input, train_target)
dtc_predict = dtc.predict(test_input)
dtc_acc = accuracy_score(test_target, dtc_predict)

# %%
print('모델 학습률 : ', dtc.score(train_input, train_target), '\n모델 테스트율 : ', dtc.score(test_input, test_target), '\n모델 테스트 평가율 : ', dtc_acc)
# Out:
# 모델 학습률 :  1.0
# 모델 테스트율 :  0.9937426102306015
# 모델 테스트 평가율 :  0.9829835507657402

# %%
# 트리모델 시각화
from sklearn.tree import plot_tree      # 결정 트리 그림으로 확인할수있는 메소드

plt.figure(figsize=(10,7))              # size 지정
plot_tree(dtc)                           # 맷폴라이브에서 트리그림 확인
plt.show()

# %%
plt.figure(figsize=(10,7))
plot_tree(dtc, max_depth=2, filled=True)

plt.show()

# %%
error발생
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 error발생
#
# NameError: name 'error발생' is not defined

# %% [markdown]
# 로지스틱 회귀는 현재 사용중인 데이터에 적합.. 이 애매해서 잠시 보류중입니다.

# %%
from sklearn.linear_model import LogisticRegression



lr = LogisticRegression(max_iter=2500, n_jobs=-1)
lr.fit(train_input, train_target)
lr_predict = lr.predict(test_input)
lr_acc = accuracy_score(test_target, lr_predict)

# %%
print('모델 학습률 : ', lr.score(train_input, train_target), '\n모델 테스트율 : ', lr.score(test_input, test_target), '\n모델 테스트 평가율 : ', lr_acc)
