# %% [markdown]
# <a href="https://colab.research.google.com/github/yangjik/yang.study/blob/main/23%EB%85%84%EC%A0%84%EB%A0%A5%EC%98%88%EC%B8%A1_%EB%94%94%ED%85%8C%EC%9D%BC%ED%95%98%EA%B2%8C_%EB%B6%84%EC%84%9D%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 구글 드라이브 연동시키는 이유.
#
# 1. 용량이 큰 csv 파일을 다루기위해.
# 2. 해당 코렙에서 직접 파일을 업로드하고 사용하면 해당 파일에서 재시작이 필요시 재업로드 필요해서.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (11.9 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %%
# 파일 경로 방법1. - 가독성 올리기
basepath = '/content/drive/MyDrive/새싹교육/코드/dacon/2023전력사용량예측/'

train_csv = basepath + 'train.csv'
test_csv =  basepath + 'test.csv'
building_csv = basepath + 'building_info.csv'

# %%
# 파일 경로 방법2. - 가독성 낮은 직접 경로 받기
train_csv = '/content/drive/MyDrive/새싹교육/코드/dacon/2023전력사용량예측/train.csv'
test_csv = '/content/drive/MyDrive/새싹교육/코드/dacon/2023전력사용량예측/test.csv'
building_csv = '/content/drive/MyDrive/새싹교육/코드/dacon/2023전력사용량예측/building_info.csv'

# %%
# 파일 경로 방법3 - 기본 패키지 os를 이용해서 파일 경로 받아오기.
import os

basepath = '/content/drive/MyDrive/새싹교육/코드/dacon/2023전력사용량예측/'
train_csv = os.path.join(basepath, 'train.csv')
test_csv = os.path.join(basepath, 'test.csv')
building_csv = os.path.join(basepath, 'building_info.csv')

# %%
# 판다스로 csv 파일 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

train_df = pd.read_csv(train_csv)
test_df = pd.read_csv(test_csv)
building_df = pd.read_csv(building_csv)

# %%
# csv 파일 정보 확인
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204000 entries, 0 to 203999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   num_date_time  204000 non-null  object
#  1   건물번호           204000 non-null  int64
#  2   일시             204000 non-null  object
#  3   기온(C)          204000 non-null  float64
#  4   강수량(mm)        43931 non-null   float64
#  5   풍속(m/s)        203981 non-null  float64
#  6   습도(%)          203991 non-null  float64
#  7   일조(hr)         128818 non-null  float64
#  8   일사(MJ/m2)      116087 non-null  float64
#  9   전력소비량(kWh)     204000 non-null  float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 15.6+ MB

# %%
# 수치 - 통계치 확인하기
train_df.describe()
# Out:
#                 건물번호          기온(C)       강수량(mm)        풍속(m/s)  \
# count  204000.000000  204000.000000  43931.000000  203981.000000
# mean       50.500000      25.543524      2.040830       2.134031
# std        28.866141       3.779523      5.165218       1.358109
# min         1.000000      10.100000      0.000000       0.000000
# 25%        25.750000      23.400000      0.000000       1.200000
# 50%        50.500000      25.700000      0.100000       2.000000
# 75%        75.250000      28.100000      1.300000       2.800000
# max       100.000000      37.100000     92.200000      13.300000
#
#                습도(%)         일조(hr)      일사(MJ/m2)     전력소비량(kWh)
# count  203991.000000  128818.000000  116087.000000  204000.000000
# mean       78.716295       0.333637       1.063823    2451.036462
# std        15.080108       0.401486       1.001030    2440.648858
# min        13.000000       0.000000       0.000000       0.000000
# ...

# %%
# 후에 머신러닝을 돌릴때 test_df에서 일조, 일사 데이터가 없으면 제거 필요.
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16800 entries, 0 to 16799
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   num_date_time  16800 non-null  object
#  1   건물번호           16800 non-null  int64
#  2   일시             16800 non-null  object
#  3   기온(C)          16800 non-null  float64
#  4   강수량(mm)        16800 non-null  float64
#  5   풍속(m/s)        16800 non-null  float64
#  6   습도(%)          16800 non-null  int64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 918.9+ KB

# %%
# 건물번호만 조회 - 데이터 타입은 시리즈 형태이다.
train_df['건물번호']
# Out:
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
#          ...
# 203995    100
# 203996    100
# 203997    100
# 203998    100
# 203999    100
# Name: 건물번호, Length: 204000, dtype: int64

# %%
# 각 건물번호의 토탈 개수
train_df['건물번호'].value_counts()
# Out:
# 1      2040
# 64     2040
# 74     2040
# 73     2040
# 72     2040
#        ...
# 31     2040
# 30     2040
# 29     2040
# 28     2040
# 100    2040
# Name: 건물번호, Length: 100, dtype: int64

# %%
# 일시 데이터는 2022.06.01 00시 ~ 2022.08.24 23시까지 구성되어있다.
train_df['일시']
# Out:
# 0         20220601 00
# 1         20220601 01
# 2         20220601 02
# 3         20220601 03
# 4         20220601 04
#              ...
# 203995    20220824 19
# 203996    20220824 20
# 203997    20220824 21
# 203998    20220824 22
# 203999    20220824 23
# Name: 일시, Length: 204000, dtype: object

# %%
# 일시 데이터는 2022.08.25 00시 ~ 2022.08.31 23시까지 구성되어있다.
test_df['일시']
# Out:
# 0        20220825 00
# 1        20220825 01
# 2        20220825 02
# 3        20220825 03
# 4        20220825 04
#             ...
# 16795    20220831 19
# 16796    20220831 20
# 16797    20220831 21
# 16798    20220831 22
# 16799    20220831 23
# Name: 일시, Length: 16800, dtype: object

# %%
# 기온
train_df['기온(C)']
# Out:
# 0         18.6
# 1         18.0
# 2         17.7
# 3         16.7
# 4         18.4
#           ...
# 203995    23.1
# 203996    22.4
# 203997    21.3
# 203998    21.0
# 203999    20.7
# Name: 기온(C), Length: 204000, dtype: float64

# %%
# 기온
test_df['기온(C)']
# Out:
# 0        23.5
# 1        23.0
# 2        22.7
# 3        22.1
# 4        21.8
#          ...
# 16795    22.5
# 16796    20.7
# 16797    20.2
# 16798    20.1
# 16799    19.1
# Name: 기온(C), Length: 16800, dtype: float64

# %%
# 빠르게 데이터 - 자동 시각화
train_df.head()
# Out:
#    num_date_time  건물번호           일시  기온(C)  강수량(mm)  풍속(m/s)  습도(%)  일조(hr)  \
# 0  1_20220601 00     1  20220601 00   18.6      NaN      0.9   42.0     NaN
# 1  1_20220601 01     1  20220601 01   18.0      NaN      1.1   45.0     NaN
# 2  1_20220601 02     1  20220601 02   17.7      NaN      1.5   45.0     NaN
# 3  1_20220601 03     1  20220601 03   16.7      NaN      1.4   48.0     NaN
# 4  1_20220601 04     1  20220601 04   18.4      NaN      2.8   43.0     NaN
#
#    일사(MJ/m2)  전력소비량(kWh)
# 0        NaN     1085.28
# 1        NaN     1047.36
# 2        NaN      974.88
# 3        NaN      953.76
# 4        NaN      986.40

# %%
# building_df 데이터에서 건물유형 고유값 확인
pd.unique(building_df['건물유형'])
# Out:
# array(['건물기타', '공공', '대학교', '데이터센터', '백화점및아울렛', '병원', '상용', '아파트', '연구소',
#        '지식산업센터', '할인마트', '호텔및리조트'], dtype=object)

# %%
# 상관계수 확인 corr()로 확인!
# 그리고 히트맵을 통해서 추가로 파악
building_df.corr()
# Out:
# <ipython-input-20-5174a5714a4d>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   building_df.corr()
#               건물번호   연면적(m2)  냉방면적(m2)
# 건물번호      1.000000 -0.115322 -0.116199
# 연면적(m2)  -0.115322  1.000000  0.998884
# 냉방면적(m2) -0.116199  0.998884  1.000000
